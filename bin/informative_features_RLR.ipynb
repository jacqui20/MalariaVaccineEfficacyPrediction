# %%
"""
Evaluation of informative features from RLR models 

Will save the results to various .tsv/.csv files


"""
# Out:
# '\nEvaluation of informative features from RLR models \n\nWill save the results to various .tsv/.csv files\n\n\n'

# %%
import argparse
import numpy as np
import os.path
import pandas as pd
import pathlib
from pprint import pprint
import scipy
import sklearn
import sys
import traceback
import warnings
# from shutil import rmtree
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# %%
sklearn.__version__
# Out:
# '0.24.2'

# %%
input_file = "/Users/schmidtj/Documents/GitHub/MalariaVaccineEfficacyPrediction/results/RLR/whole/RGSCV/RepeatedGridSearchCV_results_24.03.2022_09-23-48.tsv"
results_RLR_whole = pd.read_csv(input_file, sep="\t", index_col=0)

# %%
results_RLR_whole
# Out:
#     time               scoring  \
# 0  III14                   mcc
# 1  III14  precision_recall_auc
# 2  III14               roc_auc
# 3    C-1                   mcc
# 4    C-1  precision_recall_auc
# 5    C-1               roc_auc
# 6    C28                   mcc
# 7    C28  precision_recall_auc
# 8    C28               roc_auc
#
#                                          best_params  best_score
# 0  {'logisticregression__C': 0.1, 'logisticregres...    0.652156
# 1  {'logisticregression__C': 0.1, 'logisticregres...    0.890387
# 2  {'logisticregression__C': 0.1, 'logisticregres...    0.897096
# 3  {'logisticregression__C': 0.1, 'logisticregres...    0.730569
# 4  {'logisticregression__C': 0.1, 'logisticregres...    0.894966
# 5  {'logisticregression__C': 0.1, 'logisticregres...    0.896338
# 6  {'logisticregression__C': 1.0, 'logisticregres...    0.778867
# 7  {'logisticregression__C': 1.0, 'logisticregres...    0.920050
# 8  {'logisticregression__C': 1.0, 'logisticregres...    0.923990

# %%
def get_kernel_paramter(kernel_parameter):
    """ Returns the combination of kernel parameters from the results of the
        multitask-SVM approach based on the highest mean AUC.

        see results of the Parser_multitask_SVM.py module

        Args: kernel_parameter: results of the multitask-SVM approach as .csv file

        Returns:
            pam (list): Combination of kernel parameter for the combination of kernel functions for the
            multitask-SVM classifier
            based on the highest mean AUC value
            best_AUC (float): highest mean AUC value
        """
    pam_roc_auc = kernel_parameter[kernel_parameter['scoring'].isin(['roc_auc'])]
    pam = pam_roc_auc['best_params']
    #print(pam)
    pam = pam.str.split(" ", expand=True).values
    #print(pam)
    return pam

# %%
def select_time_point(kernel_parameter, time_point):
    """
    Selection of the time point to run ESPY measurment
    
    Parameter:
    ---------
    kernel_parameter: dataframe
        performance results per time point
    time_point: str
        preferable time point 
        
    Returns:
    --------
    X: np.darray
        matrix of performance scores per time point
    
    """
    X = kernel_parameter[kernel_parameter['time'].isin([time_point])]
    #print(X)
    return X

# %%
time_point_III14 = select_time_point(results_RLR_whole, "III14")

# %%
kernel_parameter = get_kernel_paramter(time_point_III14)

# %%
kernel_parameter
# Out:
# '0.1,'

# %%
def RLR_model(data, kernel_parameter):
    
    X_data = data.iloc[:, 5:].to_numpy()
    #print(X_data)
    y_labels = data.loc[:, 'Protection'].to_numpy()
    #print(y_labels)
    
    c = pd.to_numeric(kernel_parameter[0][1].split(",")[0])
    print("C-value:" + str(c))
    print(type(c))
    l1_value = pd.to_numeric(kernel_parameter[0][3].split("}")[0])
    print("l1_value:" + str(l1_value))
    
    estimator = make_pipeline(
            StandardScaler(
                with_mean=True,
                with_std=True,
            ),
            LogisticRegression(
                penalty='elasticnet',
                C = c,
                solver='saga',
                l1_ratio = l1_value,
                max_iter=10000,
            ),
            # memory=cachedir,
        )
    estimator.fit(X_data, y_labels)
    print(estimator)
    model = estimator[1]
    print("Non Zero weights:",np.count_nonzero(model.coef_))
    cdf = pd.concat([pd.DataFrame(data.iloc[:,5:].columns),pd.DataFrame(np.transpose(model.coef_))], axis = 1)
    cdf.columns = ['Pf_antigen_ID', 'weight']
    cdf = cdf.sort_values(by = ['weight'], ascending = True)
    cdf_nonzeros = cdf[cdf['weight'] != 0]
    return model, cdf_nonzeros

# %% [markdown]
# ## Informative features evaluation at III14

# %%
proteome_input_file = "/Users/schmidtj/Documents/GitHub/MalariaVaccineEfficacyPrediction/data/timepoint-wise/whole_data_III14.csv"
proteome_data_whole = pd.read_csv(proteome_input_file)

# %%
proteome_data_whole
# Out:
#           Patient  group  Protection  Dose  TimePointOrder  \
# 0   T2-002 III 14      2           1     1               2
# 1   T2-005 III 14      5           0     0               2
# 2   T2-006 III 14      6           1     1               2
# 3   T2-007 III 14      7           0     1               2
# 4   T2-010 III 14     10           0     2               2
# 5   T2-011 III 14     11           0     0               2
# 6   T2-012 III 14     12           0     1               2
# 7   T2-015 III 14     15           1     1               2
# 8   T2-017 III 14     17           1     3               2
# 9   T2-018 III 14     18           1     2               2
# 10  T2-022 III 14     22           0     2               2
# 11  T2-023 III 14     23           0     0               2
# 12  T2-025 III 14     25           0     0               2
# 13  T2-026 III 14     26           1     3               2
# 14  T2-028 III 14     28           0     2               2
# 15  T2-030 III 14     30           0     1               2
# 16  T2-033 III 14     33           0     0               2
# 17  T2-034 III 14     34           0     1               2
# 18  T2-035 III 14     35           1     3               2
# 19  T2-038 III 14     38           1     2               2
# 20  T2-039 III 14     39           1     2               2
# 21  T2-041 III 14     41           0     0               2
# 22  T2-042 III 14     42           1     3               2
# 23  T2-046 III 14     46           0     1               2
# 24  T2-047 III 14     47           0     0               2
# 25  T2-048 III 14     48           0     0               2
# 26  T2-049 III 14     49           1     2               2
# 27  T2-050 III 14     50           0     1               2
# 28  T2-051 III 14     51           1     3               2
# 29  T2-052 III 14     52           1     3               2
# 30  T2-053 III 14     53           0     0               2
# 31  T2-055 III 14     55           0     0               2
# 32  T2-056 III 14     56           0     0               2
# 33  T2-063 III 14     63           0     0               2
# 34  T2-064 III 14     64           1     2               2
# 35  T2-067 III 14     67           1     2               2
# 36  T2-068 III 14     68           0     0               2
# 37  T2-071 III 14     71           1     3               2
# 38  T2-072 III 14     72           1     3               2
# 39  T2-073 III 14     73           1     3               2
#
#     mal_mito_3.iso1.exon1.amp1_4066  mal_mito_2.iso1.exon1.amp1_1466  \
# 0                          7.033423                         6.357552
# 1                          8.596190                         8.481799
# 2                          9.838416                         9.589651
# 3                          6.965784                         7.451211
# 4                          6.483816                         7.977280
# 5                          0.000000                         0.000000
# 6                          7.027906                         7.499846
# 7                          0.000000                         0.000000
# 8                          0.000000                         0.000000
# 9                          0.000000                         0.000000
# 10                         4.000000                         7.214319
# 11                         0.000000                         0.000000
# 12                         0.000000                         0.000000
# 13                         0.000000                         0.000000
# 14                         0.000000                         0.000000
# 15                         0.000000                         5.727920
# 16                         7.813781                         8.726218
# 17                         0.000000                         0.000000
# 18                         0.000000                         0.000000
# 19                         0.000000                         0.000000
# 20                         0.000000                         0.000000
# 21                         4.754888                         7.199672
# 22                         0.000000                         0.000000
# 23                         0.000000                         0.000000
# 24                         0.000000                         0.000000
# 25                         0.000000                         0.000000
# 26                         8.517669                         0.000000
# 27                         6.820179                         6.727920
# 28                         0.000000                         0.000000
# 29                         0.000000                         0.000000
# 30                         9.111136                         9.162391
# 31                         7.280771                         4.614710
# 32                         0.000000                         0.000000
# 33                         6.159871                         7.108524
# 34                         0.000000                         0.000000
# 35                         0.000000                         0.000000
# 36                         0.000000                         0.000000
# 37                         0.000000                         0.000000
# 38                         0.000000                         0.000000
# 39                         0.000000                         0.000000
#
#     mal_mito_1.iso1.exon1.amp1_3777  PFL2430c_484  PFL2215w_4059  ...  \
# 0                          6.954196      3.700440       0.000000  ...
# 1                          8.840778      9.076816       9.045760  ...
# 2                         10.115694     10.676398      11.304922  ...
# 3                          7.149747     10.499846       5.066089  ...
# 4                          7.800900     10.444497       9.814582  ...
# 5                          0.000000      0.000000       0.000000  ...
# 6                          7.974415      9.063395       0.000000  ...
# 7                          0.000000      0.000000       0.000000  ...
# 8                          0.000000      0.000000       3.584963  ...
# 9                          0.000000      0.000000       0.000000  ...
# 10                         0.000000      0.000000       8.679480  ...
# 11                         0.000000      0.000000       0.000000  ...
# 12                         0.000000     10.389094       0.000000  ...
# 13                         0.000000      0.000000       0.000000  ...
# 14                         0.000000     14.229870       0.000000  ...
# 15                         0.000000     10.771489      11.430453  ...
# 16                         7.467606      9.778077       2.584963  ...
# 17                         0.000000      0.000000       0.000000  ...
# 18                         0.000000     13.507795      10.312316  ...
# 19                         0.000000      0.000000       0.000000  ...
# 20                         0.000000      0.000000       0.000000  ...
# 21                         0.000000      9.620220      10.195987  ...
# 22                         0.000000      0.000000       0.000000  ...
# 23                         0.000000      0.000000       8.092757  ...
# 24                         0.000000      0.000000       0.000000  ...
# 25                         0.000000      5.686501       0.000000  ...
# 26                         8.507795      0.000000       8.930737  ...
# 27                         7.800900      8.854868       0.000000  ...
# 28                         0.000000      7.714246       8.721099  ...
# 29                         0.000000      0.000000       0.000000  ...
# 30                         9.210671      0.000000       0.000000  ...
# 31                         0.000000      0.000000       0.000000  ...
# 32                         0.000000      0.000000       0.000000  ...
# 33                         5.857981      8.328675       8.471675  ...
# 34                         0.000000      0.000000       0.000000  ...
# 35                         0.000000      0.000000       0.000000  ...
# 36                         0.000000      0.000000       0.000000  ...
# 37                         0.000000     11.319954       0.000000  ...
# 31              5.754888              0.000000               0.000000
# 32              0.000000              7.962896               6.330917
# 33             11.226412              9.108524               8.370687
# 34              0.000000              0.000000               0.000000
# 35              0.000000              0.000000               0.000000
# 36              0.000000              0.000000               0.000000
# 37             12.617582              0.000000               0.000000
# 38              0.000000              0.000000               0.000000
# 39              0.000000              0.000000               0.000000
#
#     MAL8P1.140_4049  MAL7P1.32_5037  MAL13P1.303e4s1_1829  \
# 0          0.000000       15.327447              0.000000
# 1          8.290019        8.556506              8.873444
# 2         10.989394       13.195757             11.017504
# 3          0.000000       15.761292              6.209453
# 4         10.063395       14.122383             10.745674
# 5          0.000000        0.000000              0.000000
# 6          0.000000       12.406736              8.828136
# 7          0.000000        0.000000              0.000000
# 8          7.434628        7.312883              5.870365
# 9          8.618386        0.000000              0.000000
# 10         5.442943        0.000000              0.000000
# 11         0.000000        0.000000              0.000000
# 12        10.493355       12.103616              7.467606
# 13         0.000000        0.000000              0.000000
# 14         0.000000       10.389094              0.000000
# 15        10.554589       11.561049             10.693051
# 16         9.133142        0.000000              8.105909
# 17         8.118941        0.000000              0.000000
# 18         0.000000       13.841417              0.000000
# 19         0.000000       10.214319              0.000000
# 20         0.000000        0.000000              0.000000
# 21         8.891784        9.873444              9.571753
# 22         0.000000        6.741467              0.000000
# 23         0.000000        0.000000              7.357552
# 24         5.426265        4.954196              7.562242
# 25         6.787903        0.000000              5.266787
# 26         0.000000        0.000000              0.000000
# 27         7.651052       15.368847              0.000000
# 28         0.000000        6.714246              0.000000
# 29         0.000000        6.199672              0.000000
# 30         0.000000        5.930737              5.754888
# 31         0.000000        0.000000              0.000000
# 32         6.442943        0.000000              6.539159
# 33         7.519636       10.222795              8.672425
# 34         0.000000        0.000000              0.000000
# 35         0.000000        0.000000              0.000000
# 36         0.000000        0.000000              0.000000
# 37         0.000000       14.301139              0.000000
# 38         0.000000        0.000000              0.000000
# 39         0.000000        0.000000              0.000000
#
#     MAL13P1.303e1s1_4421
# 0               0.000000
# 1               8.961450
# 2              10.706064
# 3               0.000000
# 4               0.000000
# 5               0.000000
# 6               8.560333
# 7               0.000000
# 8               7.266787
# 9               0.000000
# 10              0.000000
# 11              0.000000
# 12              7.906891
# 13              0.000000
# 14              0.000000
# 15             10.225207
# 16              6.977280
# 17              7.214319
# 18              0.000000
# 19              0.000000
# 20              0.000000
# 21              8.920353
# 22              0.000000
# 23              0.000000
# 24              0.000000
# 25              0.000000
# 26              0.000000
# 27              5.392317
# 28              7.721099
# 29              0.000000
# 30              0.000000
# 31              0.000000
# 32              5.614710
# 33              8.396605
# 34              0.000000
# 35              0.000000
# 36              0.000000
# 37              0.000000
# 38              0.000000
# 39              0.000000
#
# [40 rows x 7460 columns]

# %%
np.all(np.isin(proteome_data_whole.dtypes.to_list()[5:], ['float64']))
# Out:
# True

# %%
def rearagne_columns(data):
    df = data.copy()
    dose = df['Dose']
    df = df.drop(columns=['Dose'])
    df.insert(loc=4, column='Dose', value=dose)
    #print(df)
    
    return df

# %%
proteome_data_whole = rearagne_columns(proteome_data_whole)

# %%
proteome_data_whole
# Out:
#           Patient  group  Protection  TimePointOrder  Dose  \
# 0   T2-002 III 14      2           1               2     1
# 1   T2-005 III 14      5           0               2     0
# 2   T2-006 III 14      6           1               2     1
# 3   T2-007 III 14      7           0               2     1
# 4   T2-010 III 14     10           0               2     2
# 5   T2-011 III 14     11           0               2     0
# 6   T2-012 III 14     12           0               2     1
# 7   T2-015 III 14     15           1               2     1
# 8   T2-017 III 14     17           1               2     3
# 9   T2-018 III 14     18           1               2     2
# 10  T2-022 III 14     22           0               2     2
# 11  T2-023 III 14     23           0               2     0
# 12  T2-025 III 14     25           0               2     0
# 13  T2-026 III 14     26           1               2     3
# 14  T2-028 III 14     28           0               2     2
# 15  T2-030 III 14     30           0               2     1
# 16  T2-033 III 14     33           0               2     0
# 17  T2-034 III 14     34           0               2     1
# 18  T2-035 III 14     35           1               2     3
# 19  T2-038 III 14     38           1               2     2
# 20  T2-039 III 14     39           1               2     2
# 21  T2-041 III 14     41           0               2     0
# 22  T2-042 III 14     42           1               2     3
# 23  T2-046 III 14     46           0               2     1
# 24  T2-047 III 14     47           0               2     0
# 25  T2-048 III 14     48           0               2     0
# 26  T2-049 III 14     49           1               2     2
# 27  T2-050 III 14     50           0               2     1
# 28  T2-051 III 14     51           1               2     3
# 29  T2-052 III 14     52           1               2     3
# 30  T2-053 III 14     53           0               2     0
# 31  T2-055 III 14     55           0               2     0
# 32  T2-056 III 14     56           0               2     0
# 33  T2-063 III 14     63           0               2     0
# 34  T2-064 III 14     64           1               2     2
# 35  T2-067 III 14     67           1               2     2
# 36  T2-068 III 14     68           0               2     0
# 37  T2-071 III 14     71           1               2     3
# 38  T2-072 III 14     72           1               2     3
# 39  T2-073 III 14     73           1               2     3
#
#     mal_mito_3.iso1.exon1.amp1_4066  mal_mito_2.iso1.exon1.amp1_1466  \
# 0                          7.033423                         6.357552
# 1                          8.596190                         8.481799
# 2                          9.838416                         9.589651
# 3                          6.965784                         7.451211
# 4                          6.483816                         7.977280
# 5                          0.000000                         0.000000
# 6                          7.027906                         7.499846
# 7                          0.000000                         0.000000
# 8                          0.000000                         0.000000
# 9                          0.000000                         0.000000
# 10                         4.000000                         7.214319
# 11                         0.000000                         0.000000
# 12                         0.000000                         0.000000
# 13                         0.000000                         0.000000
# 14                         0.000000                         0.000000
# 15                         0.000000                         5.727920
# 16                         7.813781                         8.726218
# 17                         0.000000                         0.000000
# 18                         0.000000                         0.000000
# 19                         0.000000                         0.000000
# 20                         0.000000                         0.000000
# 21                         4.754888                         7.199672
# 22                         0.000000                         0.000000
# 23                         0.000000                         0.000000
# 24                         0.000000                         0.000000
# 25                         0.000000                         0.000000
# 26                         8.517669                         0.000000
# 27                         6.820179                         6.727920
# 28                         0.000000                         0.000000
# 29                         0.000000                         0.000000
# 30                         9.111136                         9.162391
# 31                         7.280771                         4.614710
# 32                         0.000000                         0.000000
# 33                         6.159871                         7.108524
# 15        10.554589       11.561049             10.693051
# 16         9.133142        0.000000              8.105909
# 17         8.118941        0.000000              0.000000
# 18         0.000000       13.841417              0.000000
# 19         0.000000       10.214319              0.000000
# 20         0.000000        0.000000              0.000000
# 21         8.891784        9.873444              9.571753
# 22         0.000000        6.741467              0.000000
# 23         0.000000        0.000000              7.357552
# 24         5.426265        4.954196              7.562242
# 25         6.787903        0.000000              5.266787
# 26         0.000000        0.000000              0.000000
# 27         7.651052       15.368847              0.000000
# 28         0.000000        6.714246              0.000000
# 29         0.000000        6.199672              0.000000
# 30         0.000000        5.930737              5.754888
# 31         0.000000        0.000000              0.000000
# 32         6.442943        0.000000              6.539159
# 33         7.519636       10.222795              8.672425
# 34         0.000000        0.000000              0.000000
# 35         0.000000        0.000000              0.000000
# 36         0.000000        0.000000              0.000000
# 37         0.000000       14.301139              0.000000
# 38         0.000000        0.000000              0.000000
# 39         0.000000        0.000000              0.000000
#
#     MAL13P1.303e1s1_4421
# 0               0.000000
# 1               8.961450
# 2              10.706064
# 3               0.000000
# 4               0.000000
# 5               0.000000
# 6               8.560333
# 7               0.000000
# 8               7.266787
# 9               0.000000
# 10              0.000000
# 11              0.000000
# 12              7.906891
# 13              0.000000
# 14              0.000000
# 15             10.225207
# 16              6.977280
# 17              7.214319
# 18              0.000000
# 19              0.000000
# 20              0.000000
# 21              8.920353
# 22              0.000000
# 23              0.000000
# 24              0.000000
# 25              0.000000
# 26              0.000000
# 27              5.392317
# 28              7.721099
# 29              0.000000
# 30              0.000000
# 31              0.000000
# 32              5.614710
# 33              8.396605
# 34              0.000000
# 35              0.000000
# 36              0.000000
# 37              0.000000
# 38              0.000000
# 39              0.000000
#
# [40 rows x 7460 columns]

# %%
RLR_model_III14, coeffiecients_III14 = RLR_model(proteome_data_whole, kernel_parameter)
# Out:
# C-value:0.1
# <class 'numpy.float64'>
# l1_value:1.0
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('logisticregression',
#                  LogisticRegression(C=0.1, l1_ratio=1.0, max_iter=10000,
#                                     penalty='elasticnet', solver='saga'))])
# Non Zero weights: 2

# %%
coeffiecients_III14
# Out:
#                 Pf_antigen_ID    weight
# 1997   PF3D7_1306600.3o3_2037 -0.116641
# 757   PF3D7_1432100.e6s1_2174 -0.043455

# %% [markdown]
# ## Informative feature evaluation at C-1

# %%
proteome_input_file = "/Users/schmidtj/Documents/GitHub/MalariaVaccineEfficacyPrediction/data/timepoint-wise/whole_data_C-1.csv"
proteome_data_whole_C1 = pd.read_csv(proteome_input_file)

# %%
np.all(np.isin(proteome_data_whole_C1.dtypes.to_list()[5:], ['float64']))
# Out:
# True

# %%
proteome_data_whole_C1 = rearagne_columns(proteome_data_whole_C1)

# %%
time_point_C1 = select_time_point(results_RLR_whole, "C-1")

# %%
kernel_parameter_C1 = get_kernel_paramter(time_point_C1)

# %%
kernel_parameter_C1
# Out:
# array([["{'logisticregression__C':", '0.1,',
#         "'logisticregression__l1_ratio':", '0.7}']], dtype=object)

# %%
RLR_model_C1, coeffiecients_C1 = RLR_model(proteome_data_whole_C1, kernel_parameter_C1)
# Out:
# C-value:0.1
# <class 'numpy.float64'>
# l1_value:0.7
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('logisticregression',
#                  LogisticRegression(C=0.1, l1_ratio=0.7, max_iter=10000,
#                                     penalty='elasticnet', solver='saga'))])
# Non Zero weights: 13

# %%
coeffiecients_C1
# Out:
#                                  Pf_antigen_ID    weight
# 40    PFC10_API0059.iso1.exon1.amp1_short_1180 -0.172482
# 5570        PF3D7_0618300.iso1.exon1.amp1_1184 -0.136246
# 6065        PF3D7_0511700.iso1.exon4.amp1_2340 -0.119547
# 1101        PF3D7_1404600.iso3.exon5.amp1_1181 -0.118711
# 1144        PF3D7_1401900.iso1.exon4.amp1_3493 -0.096907
# 2099        PF3D7_1254300.iso1.exon2.amp1_2431 -0.061047
# 812         PF3D7_1427700.iso1.exon1.amp1_1501 -0.058478
# 7176        PF3D7_0201800.iso1.exon3.amp1_2338 -0.056893
# 2428        PF3D7_1229000.iso1.exon1.amp2_2206 -0.038080
# 740         PF3D7_1432700.iso1.exon2.amp1_1183 -0.012493
# 3290        PF3D7_1115900.iso1.exon2.amp1_4360 -0.008539
# 1106       PF3D7_1404600.iso2.exon16.amp1_1470 -0.004430
# 4277        PF3D7_0916200.iso1.exon1.amp1_2352 -0.003821

# %% [markdown]
# # Informative feature evaluation C+28

# %%
proteome_input_file = "/Users/schmidtj/Documents/GitHub/MalariaVaccineEfficacyPrediction/data/timepoint-wise/whole_data_C28.csv"
proteome_data_whole_C28 = pd.read_csv(proteome_input_file)

# %%
np.all(np.isin(proteome_data_whole_C28.dtypes.to_list()[5:], ['float64']))
# Out:
# True

# %%
proteome_data_whole_C28 = rearagne_columns(proteome_data_whole_C28)

# %%
time_point_C28 = select_time_point(results_RLR_whole, "C28")

# %%
time_point_C28
# Out:
#   time               scoring  \
# 6  C28                   mcc
# 7  C28  precision_recall_auc
# 8  C28               roc_auc
#
#                                          best_params  best_score
# 6  {'logisticregression__C': 1.0, 'logisticregres...    0.778867
# 7  {'logisticregression__C': 1.0, 'logisticregres...    0.920050
# 8  {'logisticregression__C': 1.0, 'logisticregres...    0.923990

# %%
kernel_parameter_C28 = get_kernel_paramter(time_point_C28)

# %%
kernel_parameter_C28
# Out:
# array([["{'logisticregression__C':", '1.0,',
#         "'logisticregression__l1_ratio':", '1.0}']], dtype=object)

# %%
RLR_model_C28, coeffiecients_C28 = RLR_model(proteome_data_whole_C28, kernel_parameter_C28)
# Out:
# C-value:1.0
# <class 'numpy.float64'>
# l1_value:1.0
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('logisticregression',
#                  LogisticRegression(l1_ratio=1.0, max_iter=10000,
#                                     penalty='elasticnet', solver='saga'))])
# Non Zero weights: 44

# %%
coeffiecients_C28
# Out:
#                                  Pf_antigen_ID    weight
# 3215        PF3D7_1121600.iso1.exon2.amp1_2679 -0.556014
# 6908        PF3D7_0223300.iso1.exon2.amp1_3611 -0.370055
# 21                               PFE1590w_2119 -0.271777
# 3968                    PF3D7_1002100.2o2_2704 -0.259108
# 2641                      PF3D7_1213200.1o1_57 -0.244142
# 4483        PF3D7_0833300.iso1.exon1.amp1_1870 -0.217699
# 3541                     PF3D7_1035200.1o1_117 -0.208249
# 4220                    PF3D7_0920800.e1s1_251 -0.197429
# 3486        PF3D7_1041100.iso1.exon2.amp1_3013 -0.195328
# 67                               PFB0300c_4064 -0.183568
# 4797                   PF3D7_0808200.e1s1_5118 -0.182276
# 4503        PF3D7_0831500.iso1.exon2.amp1_2951 -0.142878
# 3482         PF3D7_1041300.iso1.exon2.amp2_787 -0.109287
# 2686        PF3D7_1209500.iso2.exon2.amp1_3320 -0.105958
# 3348        PF3D7_1111800.iso1.exon1.amp1_2132 -0.096755
# 5004                   PF3D7_0726400.e5s1_1866 -0.083432
# 6562        PF3D7_0400400.iso1.exon1.amp1_1294 -0.079442
# 2074        PF3D7_1300900.iso1.exon1.amp1_4455 -0.079180
# 6907        PF3D7_0223400.iso1.exon2.amp1_1856 -0.058882
# 6222        PF3D7_0425800.iso1.exon2.amp1_4183 -0.054740
# 2509  PF3D7_1223800.iso1.exon1.amp1_short_2872 -0.045088
# 1017                   PF3D7_1410400.e1s1_2878 -0.043889
# 1534        PF3D7_1343800.iso1.exon1.amp4_1088 -0.041130
# 1088                    PF3D7_1405500.1o1_2703 -0.040049
# 7095                   PF3D7_0207600.e2s1_4137 -0.034608
# 1144        PF3D7_1401900.iso1.exon4.amp1_3493 -0.023135
# 2080        PF3D7_1300400.iso1.exon2.amp1_1295 -0.018180
# 2294        PF3D7_1237900.iso1.exon1.amp1_4591 -0.015187
# 2836         PF3D7_1150400.iso1.exon2.amp1_714 -0.014933
# 3822        PF3D7_1014000.iso1.exon6.amp1_1249 -0.013615
# 4482        PF3D7_0833400.iso1.exon3.amp1_4185 -0.013538
# 2070        PF3D7_1301600.iso1.exon4.amp2_1680 -0.011885
# 1896        PF3D7_1314500.iso1.exon2.amp1_2631 -0.000195
# 3182        PF3D7_1123200.iso1.exon1.amp1_3335  0.002354
# 5972                   PF3D7_0518700.e3s1_3800  0.004064
# 174                     PF3D7_1473000.1o1_4886  0.012987
# 1124                   PF3D7_1403300.e1s2_3828  0.026610
# 2898                   PF3D7_1145400.e1s1_4164  0.085440
# 7224                     PF3D7_0113300.2o2_759  0.087933
# 3106                   PF3D7_1129000.e2s1_2830  0.143749
# 7276                   PF3D7_0109100.e2s1_2105  0.155348
# 187                    PF3D7_1472200.e1s3_5059  0.220487
# 4850                     PF3D7_0804500.e3_3113  0.285664
# 62                               PFC0210c_2763  0.575374

# %% [markdown]
# # Evaluation of informatives features from selective set

# %%
input_file2 = "/Users/schmidtj/Documents/GitHub/MalariaVaccineEfficacyPrediction/results/RLR/selective/RGSCV/RepeatedGridSearchCV_results_24.03.2022_12-47-24.tsv"
results_RLR_selective = pd.read_csv(input_file2, sep="\t", index_col=0)

# %%
results_RLR_selective
# Out:
#     time               scoring  \
# 0  III14                   mcc
# 1  III14  precision_recall_auc
# 2  III14               roc_auc
# 3    C-1                   mcc
# 4    C-1  precision_recall_auc
# 5    C-1               roc_auc
# 6    C28                   mcc
# 7    C28  precision_recall_auc
# 8    C28               roc_auc
#
#                                          best_params  best_score
# 0  {'logisticregression__C': 0.1, 'logisticregres...    0.676579
# 1  {'logisticregression__C': 0.1, 'logisticregres...    0.900958
# 2  {'logisticregression__C': 0.1, 'logisticregres...    0.909343
# 3  {'logisticregression__C': 0.1, 'logisticregres...    0.698802
# 4  {'logisticregression__C': 0.1, 'logisticregres...    0.905956
# 5  {'logisticregression__C': 0.1, 'logisticregres...    0.893687
# 6  {'logisticregression__C': 1.0, 'logisticregres...    0.779430
# 7  {'logisticregression__C': 1.0, 'logisticregres...    0.944973
# 8  {'logisticregression__C': 1.0, 'logisticregres...    0.948232

# %% [markdown]
# # at III14

# %%
proteome_input_file1 = "/Users/schmidtj/Documents/GitHub/MalariaVaccineEfficacyPrediction/data/timepoint-wise/selective_data_III14.csv"
proteome_data_selective_III14 = pd.read_csv(proteome_input_file1)

# %%
np.all(np.isin(proteome_data_selective_III14.dtypes.to_list()[5:], ['float64']))
# Out:
# True

# %%
proteome_data_selective_III14 = rearagne_columns(proteome_data_selective_III14)

# %%
time_point_s_III14 = select_time_point(results_RLR_selective, "III14")

# %%
time_point_s_III14
# Out:
#     time               scoring  \
# 0  III14                   mcc
# 1  III14  precision_recall_auc
# 2  III14               roc_auc
#
#                                          best_params  best_score
# 0  {'logisticregression__C': 0.1, 'logisticregres...    0.676579
# 1  {'logisticregression__C': 0.1, 'logisticregres...    0.900958
# 2  {'logisticregression__C': 0.1, 'logisticregres...    0.909343

# %%
kernel_parameter_s_III14 = get_kernel_paramter(time_point_s_III14)

# %%
kernel_parameter_s_III14
# Out:
# array([["{'logisticregression__C':", '0.1,',
#         "'logisticregression__l1_ratio':", '0.9}']], dtype=object)

# %%
RLR_model_s_III14, coeffiecients_s_III14 = RLR_model(proteome_data_selective_III14, kernel_parameter_s_III14)
# Out:
# C-value:0.1
# <class 'numpy.float64'>
# l1_value:1.0
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('logisticregression',
#                  LogisticRegression(C=0.1, l1_ratio=1.0, max_iter=10000,
#                                     penalty='elasticnet', solver='saga'))])
# Non Zero weights: 2

# %%
coeffiecients_s_III14
# Out:
#                Pf_antigen_ID    weight
# 277  PF3D7_1209300.e1s2_2212 -0.050442
# 315  PF3D7_1201000.e2s1_2210 -0.008373

# %% [markdown]
# # at C-1

# %%
proteome_input_file2 = "/Users/schmidtj/Documents/GitHub/MalariaVaccineEfficacyPrediction/data/timepoint-wise/selective_data_C-1.csv"
proteome_data_selective_C1 = pd.read_csv(proteome_input_file2)

# %%
np.all(np.isin(proteome_data_selective_C1.dtypes.to_list()[5:], ['float64']))
# Out:
# True

# %%
proteome_data_selective_C1 = rearagne_columns(proteome_data_selective_C1)

# %%
time_point_s_C1 = select_time_point(results_RLR_selective, "C-1")

# %%
kernel_parameter_s_C1 = get_kernel_paramter(time_point_s_C1)

# %%
kernel_parameter_s_C1
# Out:
# array([["{'logisticregression__C':", '0.1,',
#         "'logisticregression__l1_ratio':", '0.7}']], dtype=object)

# %%
RLR_model_s_C1, coeffiecients_s_C1 = RLR_model(proteome_data_selective_C1, kernel_parameter_s_C1)
# Out:
# C-value:0.1
# <class 'numpy.float64'>
# l1_value:0.7
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('logisticregression',
#                  LogisticRegression(C=0.1, l1_ratio=0.7, max_iter=10000,
#                                     penalty='elasticnet', solver='saga'))])
# Non Zero weights: 7

# %%
coeffiecients_s_C1
# Out:
#                            Pf_antigen_ID    weight
# 390   PF3D7_1115900.iso1.exon2.amp1_4360 -0.256785
# 260   PF3D7_1229000.iso1.exon1.amp2_2206 -0.222281
# 915   PF3D7_0514500.iso1.exon6.amp1_1487 -0.138857
# 1026  PF3D7_0400100.iso1.exon2.amp1_4192 -0.083968
# 826   PF3D7_0632800.iso1.exon1.amp1_4482 -0.025289
# 600   PF3D7_0832700.iso1.exon2.amp1_2380 -0.021632
# 1130  PF3D7_0200200.iso1.exon1.amp1_1284 -0.019726

# %% [markdown]
# # at C28

# %%
proteome_input_file3 = "/Users/schmidtj/Documents/GitHub/MalariaVaccineEfficacyPrediction/data/timepoint-wise/selective_data_C28.csv"
proteome_data_selective_C28 = pd.read_csv(proteome_input_file3)

# %%
np.all(np.isin(proteome_data_selective_C28.dtypes.to_list()[5:], ['float64']))
# Out:
# True

# %%
proteome_data_selective_C28 = rearagne_columns(proteome_data_selective_C28)

# %%
time_point_s_C28 = select_time_point(results_RLR_selective, "C28")

# %%
kernel_parameter_s_C28 = get_kernel_paramter(time_point_s_C28)

# %%
kernel_parameter_s_C28
# Out:
# array([["{'logisticregression__C':", '1.0,',
#         "'logisticregression__l1_ratio':", '1.0}']], dtype=object)

# %%
RLR_model_s_C28, coeffiecients_s_C28 = RLR_model(proteome_data_selective_C28, kernel_parameter_s_C28)
# Out:
# C-value:1.0
# <class 'numpy.float64'>
# l1_value:1.0
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('logisticregression',
#                  LogisticRegression(l1_ratio=1.0, max_iter=10000,
#                                     penalty='elasticnet', solver='saga'))])
# Non Zero weights: 17

# %%
coeffiecients_s_C28
# Out:
#                            Pf_antigen_ID    weight
# 383   PF3D7_1121600.iso1.exon2.amp1_2679 -1.079886
# 1073  PF3D7_0223300.iso1.exon2.amp1_3611 -0.579821
# 0                          PFE1590w_2119 -0.478398
# 439                PF3D7_1035200.1o1_117 -0.350594
# 416   PF3D7_1041100.iso1.exon2.amp1_3013 -0.337831
# 3                          PFB0300c_4064 -0.335427
# 594   PF3D7_0833300.iso1.exon1.amp1_1870 -0.169680
# 606   PF3D7_0831500.iso1.exon2.amp1_2951 -0.162559
# 593   PF3D7_0833400.iso1.exon3.amp1_4185 -0.144171
# 721              PF3D7_0726400.e5s1_1866 -0.096919
# 805              PF3D7_0703700.e1s1_4460 -0.095967
# 1015  PF3D7_0401000.iso1.exon1.amp1_2432 -0.059937
# 412    PF3D7_1041300.iso1.exon2.amp2_787 -0.038874
# 978               PF3D7_0419700.1o1_3942 -0.003283
# 1151               PF3D7_0113300.2o2_759  0.113187
# 663                PF3D7_0804500.e3_3113  0.622231
# 2                          PFC0210c_2763  0.834027
